# %%
import pandas
import torch
import torch
from transformers import AutoModel, AutoTokenizer

# %%
data = pandas.read_csv("data.csv")

# %%
tokenizer = AutoTokenizer.from_pretrained("avsolatorio/NoInstruct-small-Embedding-v0")

# %%
tok = [tokenizer.encode(s) for s in data['short_description']]

# %%
# token number
tok_len = [len(t) for t in tok]
# average number of tokens per description
print(sum(tok_len) / len(tok_len))
import matplotlib.pyplot as plt
plt.hist(tok_len, bins=20)
# Out:
# 39.11473087818697
# (array([ 11.,  12.,  31.,  66.,  88., 109., 112.,  61.,  52.,  56.,  39.,
#          20.,  18.,  11.,  12.,   2.,   3.,   0.,   2.,   1.]),
#  array([  3. ,   8.3,  13.6,  18.9,  24.2,  29.5,  34.8,  40.1,  45.4,
#          50.7,  56. ,  61.3,  66.6,  71.9,  77.2,  82.5,  87.8,  93.1,
#          98.4, 103.7, 109. ]),
#  <BarContainer object of 20 artists>)

# %%
model = AutoModel.from_pretrained("avsolatorio/NoInstruct-small-Embedding-v0")
model.eval()
# Out:
# BertModel(
#   (embeddings): BertEmbeddings(
#     (word_embeddings): Embedding(30522, 384, padding_idx=0)
#     (position_embeddings): Embedding(512, 384)
#     (token_type_embeddings): Embedding(2, 384)
#     (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#   )
#   (encoder): BertEncoder(
#     (layer): ModuleList(
#       (0-11): 12 x BertLayer(
#         (attention): BertAttention(
#           (self): BertSdpaSelfAttention(
#             (query): Linear(in_features=384, out_features=384, bias=True)
#             (key): Linear(in_features=384, out_features=384, bias=True)
#             (value): Linear(in_features=384, out_features=384, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): BertSelfOutput(
#             (dense): Linear(in_features=384, out_features=384, bias=True)
#             (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate): BertIntermediate(
#           (dense): Linear(in_features=384, out_features=1536, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output): BertOutput(
#           (dense): Linear(in_features=1536, out_features=384, bias=True)
#           (LayerNorm): LayerNorm((384,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
#   (pooler): BertPooler(
#     (dense): Linear(in_features=384, out_features=384, bias=True)
#     (activation): Tanh()
#   )
# )

# %%
with torch.no_grad():
    embed = [model(v).last_hidden_state[:, 0, :] for v in tok]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 with torch.no_grad():
# ----> 2     embed = [model(v).last_hidden_state[:, 0, :] for v in tok]
#
# Cell In[17], line 2, in <listcomp>(.0)
#       1 with torch.no_grad():
# ----> 2     embed = [model(v).last_hidden_state[:, 0, :] for v in tok]
#
# File ~/Projects/ramdam/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/Projects/ramdam/env/lib/python3.9/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Projects/ramdam/env/lib/python3.9/site-packages/transformers/models/bert/modeling_bert.py:1057, in BertModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1055     raise ValueError("You cannot specify both input_ids and inputs_embeds at the same time")
#    1056 elif input_ids is not None:
# -> 1057     self.warn_if_padding_and_no_attention_mask(input_ids, attention_mask)
#    1058     input_shape = input_ids.size()
#    1059 elif inputs_embeds is not None:
#
# File ~/Projects/ramdam/env/lib/python3.9/site-packages/transformers/modeling_utils.py:4982, in PreTrainedModel.warn_if_padding_and_no_attention_mask(self, input_ids, attention_mask)
#    4979     return
#    4981 # Check only the first and last input IDs to reduce overhead.
# -> 4982 if self.config.pad_token_id in input_ids[:, [-1, 0]]:
#    4983     warn_string = (
#    4984         "We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See "
#    4985         "https://huggingface.co/docs/transformers/troubleshooting"
#    4986         "#incorrect-output-when-padding-tokens-arent-masked."
#    4987     )
#    4989     # If the pad token is equal to either BOS, EOS, or SEP, we do not know whether the user should use an
#    4990     # attention_mask or not. In this case, we should still show a warning because this is a rare case.
#
# TypeError: list indices must be integers or slices, not tuple

# %%
# def get_embedding(text: Union[str, list[str]], mode: str = "sentence"):
#     model.eval()

#     assert mode in ("query", "sentence"), f"mode={mode} was passed but only `query` and `sentence` are the supported modes."

#     if isinstance(text, str):
#         text = [text]

#     inp = tokenizer(text, return_tensors="pt", padding=True, truncation=True)

#     with torch.no_grad():
#         output = model(**inp)

#     # The model is optimized to use the mean pooling for queries,
#     # while the sentence / document embedding uses the [CLS] representation.

#     if mode == "query":
#         vectors = output.last_hidden_state * inp["attention_mask"].unsqueeze(2)
#         vectors = vectors.sum(dim=1) / inp["attention_mask"].sum(dim=-1).view(-1, 1)
#     else:
#         vectors = output.last_hidden_state[:, 0, :]

#     return vectors

# %%
# texts = [
#     "Illustration of the REaLTabFormer model. The left block shows the non-relational tabular data model using GPT-2 with a causal LM head. In contrast, the right block shows how a relational dataset's child table is modeled using a sequence-to-sequence (Seq2Seq) model. The Seq2Seq model uses the observations in the parent table to condition the generation of the observations in the child table. The trained GPT-2 model on the parent table, with weights frozen, is also used as the encoder in the Seq2Seq model.",
#     "Predicting human mobility holds significant practical value, with applications ranging from enhancing disaster risk planning to simulating epidemic spread. In this paper, we present the GeoFormer, a decoder-only transformer model adapted from the GPT architecture to forecast human mobility.",
#     "As the economies of Southeast Asia continue adopting digital technologies, policy makers increasingly ask how to prepare the workforce for emerging labor demands. However, little is known about the skills that workers need to adapt to these changes"
# ]

# # Compute embeddings
# embeddings = get_embedding(texts, mode="sentence")

# %%
# embeddings

# %%
import pandas
data = pandas.read_csv("data.csv")
data['short_description'].to_list()
# Out:
# ['Embark on a personalized wellness journey with Beyond Body – tailored 28-day meal plans, custom workout routines, mindfulness techniques, and habit-building strategies designed to boost health and confidence.',
#  'Seeking creators to create UGC-style videos highlighting how our dating app stands out and showcasing its key features.',
#  'Play around with Ism Lens for that cool twist, and breeze through edits with our easy copy-paste. It’s all about your vibe, your vision. Ready to remix your pics? ',
#  "Promouvoir Officiel QI Test, un service de test de QI en ligne qui évalue l'intelligence de manière innovante et précise.",
#  "Dans cette campagne on commence par un hook où vous mentionnez avoir été influencé par TikTok, avant de donner des précisions sur l'application Joko.",
#  'Capture is the representation of your real life relationships. No influencers, no brands, no likes, no algorithms – just you and your friends sharing moments of your lives as you live them… with a surprise.',
#  'To create ad video to promote the value of Yubo : "Yubo is a platform that helps you make friend confidently. Believe in yourself when being friend with your tribe on Yubo". The ultimate objective is to have user download the app ',
#  "Dans cette campagne un papa se prépare en mode commando pour Black Friday en regardant toutes les offres de mega cashback sur Joko. Il veut faire plein d'économies.\n\nhttps://www.tiktok.com/@justfabonline/video/7304385152917196078?lang=en",
#  'The only platform with ALL accommodations available, and the only one in the world listing Airbnb offers.',
#  'Mojo é um aplicativo de criação de conteúdo social projetado para ajudar os usuários a criar Insta Stories, Reels e publicações em redes sociais impressionantes e envolventes.',
#  'Strides is a powerful app for tracking all your goals and habits in one place. With four flexible types you can build habits, achieve goals, complete projects on time, stay motivated and always feel organized.',
#  "Join SpongeBob and friends on a mission to restore Bikini Bottom in the exciting 'SpongeBob Adventures' game!",
#  "Le concept est simple : ️des vendeurs montrent leur sélection d'objets en live et lancent des enchères, souvent à prix de départ à 1€ pour pimenter la vente. Les acheteurs échangent en live dans le chat et posent des questions.",
#  "On veut faire connaître Yumi aux utilisateurs de TikTok, qui rêvent de chatter avec les célébrités qu'ils admirent ou qui souhaitent créer plus de lien.",
#  'Únete a nuestra campaña para Weapon Master: ¡Gun Shooter Run! Experimenta un emocionante tiroteo y una elaboración estratégica en este juego lleno de acción.',
#  'Showcase the exciting and engaging Blitz Win Cash app where users can play games and stand a chance to win daily cash prizes.',
#  "Promoting 'Blitz Win Cash' by replicating a given video in a unique style, highlighting the fun of playing games and winning real cash.",
#  'Transform your sports broadcasting with Swish Live. Manage real-time scoreboards, stream on Facebook and boost sponsor visibility. Supports multiple sports with real-time commentary.',
#  'Embark on a thrilling journey with The Oregon Trail: Boom Town! Build, grow, harvest, and transform a small village into a thriving town.',
#  'Mob Control is a thrilling mobile game where you create massive mobs by shooting through multiplier gates, unlocking powerful combinations of cannons, mobs, and champions, and leveling up your combo to rise at the top of the League.',
#  'Showcase the fun of Yubo, and how you can have a trustful online friends. ',
#  'Swipewipe is the app that will (finally) help you clean up your camera roll. And you’ll enjoy reminiscing while you do it.',
#  'Yubo est une application qui permet de se faire des amis avec le même intérêt, autour de toi ou dans le monde entier. ',
#  'Faites la promo de la série "Love 4 a Walk" sur l\'application WEBTOON ! ',
#  "L’objectif est d’accroître la notoriété en tant que comparateur de voyages, soulignant la simplicité et l'exhaustivité des offres & partenaires pour trouver les meilleures offres de voyage. ",
#  "Specific Australian campaign: targeting only users in Australia.\nJoin the global friendship campaign with Wizz! Meet new friends in a positive and safe community. Let's bring the world closer.",
#  '"PhotoRoom" is a mobile photo editing app, designed to make your product images and marketing materials look professional and appealing.',
#  "Discover Wemoms, your ultimate pregnancy companion! Track your baby's daily growth and visualize their development with our 3D baby tracker. Embrace the journey to parenthood with personalized insights and a seamless, user-friendly experience",
#  'Join the trend and promote Fruitz, a unique, values-driven dating app with a fun twist. Help users discover their perfect match based on their personal dating preferences.',
#  'Join us in promoting Weasyo, empowering users to manage finances with ease.',
#  'Tomplay est une application de partitions musicales innovante avec un large catalogue et des outils pour personnaliser votre expérience de jeu. Faites vivre votre pratique de la musique !',
#  "The objective is to encourage users to download the game and then make a purchase. To do this, we'd like the acting approach to be really to attract the user to come and play with us.",
#  'With PNK, teenagers can discover new friends with shared interests in a safe and fun environment. Find your perfect friend match with ease!',
#  'Yubo is a social platform aimed at helping users make new friends all around the world.',
#  'Unleash your creativity with Reverse Coloring Book App. It has colors, you draw the lines! Reverse Coloring App is a totally new idea in creativity and mindfulness: so simple, and so profoundly satisfying. ',
#  "Dans cette campagne on commence par un hook de doute =>  C'est gratuit ? C'est pas gratuit, ok c'est gratuit.",
#  'Point72 Ventures, a global VC fund, supports visionary founders in fintech, deep tech, and enterprise tech from seed to IPO, leveraging industry knowledge for investment guidance.',
#  'Entdecken Sie Wizz, eine unterhaltsame und sichere Plattform, auf der Sie neue Freunde aus der ganzen Welt kennen lernen können.',
#  'Typology is a French skincare brand : Our mission: We make naturally active, effective and sustainable skincare, specifically personalized to each typology of skin. We value efficiency.',
#  'Introduce LiftBuddy to your followers. Show them how this app keeps your weightlifting program and diet management on track while still allowing you to eat your favorite foods',
#  'Junte-se ao WeWard e transforme seus passos em prêmios. Supere desafios, suba no placar e apoie suas caridades favoritas enquanto você caminha.',
#  "L'objectif de la vidéo est de mettre en avant le choix de produit dans la box beauté du mois de mars. En effet, sur les 5 produits de la box beauté, 1 est personnalisable. C'est à vous de la choisir ! ",
#  "Feel est une application d'autothérapie pour aider à gérer la dépression grâce aux Thérapies Cognitives et Comportementales, avec des exercices pratiques et des vidéos conçues par des psychiatres.",
#  'Selency, votre brocante en ligne pour acheter et vendre des meubles d’occasion et des objets déco de seconde main. Chinez sans bouger de votre canapé !',
#  'Graff - Rewrite the online representation rules. Express freely, add favorites, and invite friends to participate. Be authentic, be you.',
#  'BeReal is an authentic social app making every interaction genuine and effortless, connecting you with close friends through daily, synchronized, real-time sharing.',
#  "Discover a new world with OneTake! Capture, swap &amp; connect through photos. Share your story, discover others'. Join the OneTake community today.",
#  'Yubo is a social platform aimed at helping users make new friends all around the world.',
#  'Découvrez CALENDR, un outil pour suivre vos créateurs préférés et ne plus manquer leurs événements. Partagez votre calendrier, restez informé des nouveautés et collaborez avec la communauté.',
#  'Promote the dating app, Hily, which prioritizes genuine relationships and boasts over 28 million users worldwide.',
#  'Macadam: An app that motivates your fitness journey by converting every step you take into Euros. Track your activity, burn calories, earn virtual coins, and claim real money!',
#  "PicMystery, votre jeu de puzzle préféré. Plongez dans un monde d'énigmes visuelles, relevez des défis quotidiens, défiez vos amis en mode multijoueur et explorez une aventure solo enrichissante.",
#  'Introducing Wizz, a fun and safe space where you can meet new friends from all over the world',
#  "Partagez votre expérience avec Axonaut, l'application de gestion d'entreprise tout-en-un, de manière engageante et amusante. Montrez comment Axonaut a simplifié votre travail.",
#  "It's spooky season 🎃\nStruggling to pick a movie with your partner? We got you! Swipe through a collection of movies together to find a match. Swipe, Match, Watch!",
#  "Le but est de mettre en avant l'assurance Malus Allianz et d'inciter les utilisateurs à faire un devis sur le site Allianz.",
#  'Discover your perfect car with All Autos Listed! Choose from thousands of new and used cars of various makes and models. Find the best deals in your area.',
#  'Dans cette campagne une maman essaye plusieurs tenues selon son style comme sur cette video \n1. La maman cool avec ASOS\n2. La maman sportive avec Nike\n3. La maman coquette avec Sephora\n4. La maman boss avec Zalando',
#  'Join us in promoting Wizz. We trust you to continue pushing the limits and delivering fresh, engaging content',
#  "Emphasizing Charm's versatility and quality craftsmanship through engaging visuals and highlighting its usage in day-to-day life.",
#  'Showcase the fun and safety of Yubo, and how it brings like-minded people together globally through live chats and user tags.',
#  'Discover infinite ways to personalize your phone with the Zedge app. From HD wallpapers to unique ringtones and AI-generated art. Be unique with Zedge.',
#  'To create ad video to promote the value of Yubo : "Yubo is a platform that helps you make friend confidently. Believe in yourself when being friend with your tribe on Yubo". The ultimate objective is to have user download the app ',
#  "Le but est de mettre en avant l'assurance Chien Chat Allianz et d'inciter les utilisateurs à faire un devis sur le site Allianz. L’assurance chiens chat est souvent souscrite à l’issue de la 1ère visite chez le vétérinaire et plus souvent par des jeunes.",
#  "L'idée de cette campagne est de faire de la pédagogie sur le cashback : il s'agit de faire une vidéo assez longue où vous allez expliquer ce qu'est le cashback, présenter votre expérience et recommander Joko comme la meilleure appli selon vous.",
#  'Join us in promoting Wizz. We trust you to continue pushing the limits and delivering fresh, engaging content',
#  'Create an engaging and authentic video showcasing how you use the Odysound app throughout your day. Highlight how the app seamlessly integrates into your routine for focus, relaxation, and better sleep.\n',
#  "Launching an exciting campaign for AVA! AVA, an AI-powered dating app, is your ultimate wingwoman, saving time, offering advice, and making you laugh. Join us to promote AVA subtly and creatively. Let's collaborate and have fun! 🚀",
#  'Join the Mojo campaign! Create a TikTok Wrapped and post it with a fun caption, or react to your own TikTok Wrapped. Help us boost Mojo’s visibility.',
#  'ten ten turns your phone into a walkie talkie, simply hold to talk and your friends will hear you instantly on their phone (even if the app is closed)',
#  'With over a million downloadDecor Match is a free home design game that lets you design, decorate and personalize your dream home.',
#  "Le but est de mettre en avant l'assurance Chien Chat Allianz et d'inciter les utilisateurs à faire un devis sur le site Allianz. L’assurance chiens chat est souvent souscrite à l’issue de la 1ère visite chez le vétérinaire et plus souvent par des jeunes.",
#  'Entdecken Sie tolle Angebote mit der Shoop Cashback App. Es ist sicher, Daten werden nicht verkauft und es ist KOSTENLOS! Der Call-to-Action für die Kampagne ist, dass die Community aufgefordert wird, auf den Link zu klicken um mehr Infos zu erhalten. ',
#  'Stay ahead on your Spotify stats with must.fm app. Find out top songs, albums, artists anytime. Real-time music insights at your fingertips!',
#  'Le site "My True Companion" propose un test de compatibilité amoureuse pour évaluer la compatibilité des couples. En répondant à une série de questions, les utilisateurs obtiennent une note de 1 à 10, indiquant la probabilité de succès de leur relation.',
#  'Faites la promo de la série "Love 4 a Walk" sur l\'application WEBTOON ! ',
#  "Bousculez votre routine avec Staycation! Profitez d'expériences uniques dans les plus beaux hôtels proches de chez vous. Pour tous les moments, réservez votre Staycation en un clic",
#  'Entdecken Sie Wizz, eine unterhaltsame und sichere Plattform, auf der Sie neue Freunde aus der ganzen Welt kennen lernen können.',
#  'Through its unique learning platform, Tomplay offers all musicians the possibility to play their instrument along with high quality recordings from professional musicians. ',
#  'To create ad video to promote the value of Yubo : "Yubo is a platform that helps you make friend confidently. Believe in yourself when being friend with your tribe on Yubo". The ultimate objective is to have user download the app ',
#  '-',
#  'Alma Studio est une plateforme avec plus de 600 histoires audio originales pour les enfants âgés de 2 à 10 ans. ',
#  "Dans cette campagne on commence par un hook où vous avez l'air choqué parce ce que vous venez de découvrir.",
#  'Promoting Wemoms, a global platform for moms to connect, share experiences, and provide mutual support with features like mom-matching, forums, and chats.',
#  'With PNK, teenagers can discover new friends with shared interests in a safe and fun environment. Find your perfect friend match with ease!',
#  'Exposed is the best game for you to know what your friends think about you.',
#  'Mojo is a social content maker app designed to help users create stunning and engaging Insta Stories, Reels, and social media posts.',
#  "Promotion du single 'Papa & Maman' d'Alien par un reel Instagram de 15 secondes minimum avec le son fourni, une émotion contextuelle et le lip sync des paroles.",
#  'Soum is a Saudi Arabian App that facilitates second hand commerce for electronic devices such as smartphones, tablets, smart watches, earphones etc.. ',
#  'Découvrez comment une maman utilise Joko pour gérer le budget familial et économiser sur les courses quotidiennes.',
#  'Build your beauty empire in Perfect Beauty Salon. Control each detail, transform clients, take on project makeovers, unlock new business areas, automate success, and become a top beauty tycoon.',
#  'Mojo is a social content maker app designed to help users create stunning and engaging Insta Stories, Reels, and social media posts.',
#  'Get your dream car with Loans Canada! Simple approval, flexible payments and available for all credit scores. No SIN (Social Insurance Number) needed!',
#  'A mobile app that rewards users for walking. ',
#  'Mojo is a social content maker app designed to help users create stunning and engaging Insta Stories, Reels, and social media posts.',
#  "Break free from the monotony of conventional dating apps. Let Ava, your AI-powered dating app, pave the way for authentic, unposed connections. Let's keep dating 100% real.",
#  'Be a part of the Fitz revolution and showcase your unique style with personalized outfit ratings and fashion tips.',
#  'Encourage mindful shopping this Black Friday with AppBlock. Resist sales fever, block distractions and focus on what matters. Download AppBlock for a thoughtful Black Friday shopping experience!',
#  'Join Blitz Win Cash - an exciting gaming app where you can play, compete, and win real cash prizes. Instant withdrawals available. Download today!',
#  'A mobile app that rewards users for walking. ',
#  'An app that turns any video you make into a perfectly edited movie.',
#  'Nous aimerons mettre en avant nos avis positifs sur TrustPilot avec quelques courtes vidéos (pas plus de 20 secondes). ',
#  'We want to attract new users to download Multipolls. The app gives users a vaste selection of surveys and polls, and the users will start earning from the first survey. surveys are matched to the users based on AI so they are relevant.',
#  'Create viral videos swapping faces with celebrities via our Magic Touch app! Aim to evoke emotion and have fun.',
#  'To create ad video to promote the value of Yubo : "Yubo is a platform that helps you make friend confidently. Believe in yourself when being friend with your tribe on Yubo". The ultimate objective is to have user download the app ',
#  'Dans cette campagne, on débute la vidéo en montrant que la cagnotte Joko se transforme concrètement en cash',
#  'Augment.org offers premium online business education from renowned founders. Boost your confidence, knowledge, and job market competitiveness with real-world insights and business certificates.',
#  'Struggling to pick a movie with your partner? We got you! Swipe through a collection of movies together to find a match. Swipe, Match, Watch!',
#  'An innovative, global gaming sensation that lets trainers around the world discover and catch Pokémon in their own real-life surroundings.',
#  "L'huile de douche Sanex Natural prebiotic SURGRAS pour peaux sèches à très sèches nettoie, nourrit et protège votre peau, tout en renforçant sa barrière naturelle. Testé dermatologiquement, vegan et sans sulfates.",
#  'Wizz in the UK! Promote the app by showcasing Wizz as a fun, safe, and diverse social app featuring a positive community and unique features like interest-based groups. Highlight that you can find great friendships all over the UK and/or in London. ',
#  'Ramdam Test Campaign',
#  "L'app ultime pour les créateurs de contenu qui veulent être payés pour promouvoir des applications !",
#  'Vocalz é um aplicativo de mensagens intuitivo alimentado por IA que permite transcrição sem esforço, conversão de texto em fala e de fala em texto! ',
#  'Gear up for 2024 with our Vision Board app and help your followers achieve their goals. The goal of this campaign is to increase visibility of our app. ',
#  'Say yes to Swipewipe and no more to a cluttered camera roll. Easily swipe right or left to choose what to keep, making your precious moments more accessible!',
#  'Mach deine Welt mit der Color Pop-App bunter. Färbe, teile und lass dich von der Gemeinschaft inspirieren.',
#  'Alma Studio est la 1ère application en France d’histoires audio pour enfants, sans écran. Quand l’histoire commence l’écran s’éteint.',
#  "Découvre Yumi, une plateforme d'IA pour des interactions authentiques avec tes créateurs préférés. Achète du contenu exclusif, reçois des conseils et élargis ton horizon social.",
#  'HelloFresh is a meal kit delivery service that provides fresh, high-quality ingredients and a variety of recipes directly to your doorstep.',
#  'Swipewipe is the app that will (finally) help you clean up your camera roll. And you’ll enjoy reminiscing while you do it.',
#  'Boost productivity with TaskyCal, turning your calendar into actionable tasks. Efficient planning, smarter calendar.',
#  'Promote TikDown, the go-to app for effortlessly downloading TikTok videos without watermarks, making content sharing a breeze.',
#  "Effortlessly preview, plan and beautify your Instagram feed with 'Feed Preview'. Our app streamlines and steps up your Instagram experience without needing to login.",
#  "When traditional weight loss methods have failed you, you've tried Hypnozio hypnotherapy and your wellbeing has significantly improved. Sharing your personal story, your struggles with weight loss.",
#  'A safe space where you can let loose and meet new friends from all over the world!   ',
#  'Show users how to explore, experiment, and express their style with Fashion Verse app. Highlight various style trends.',
#  'Feed Preview, saving time and enhancing Instagram aesthetics with planning, scheduling, and stunning filters. Preview changes before going live!',
#  'We want to attract new users to download Multipolls. The app gives users a vaste selection of surveys and polls, and the users will start earning from the first survey. surveys are matched to the users based on AI so they are relevant.',
#  'Potencia tu inteligencia con nuestra prueba de IQ en línea. Evalúa tu memoria, reacción, visión y concentración al instante.',
#  'Show how Fashionverse can help balance your outfits, explore and discover your creativity with a wide array of fashion styles !',
#  "Transformez votre esprit avec Deep Belief, une application d'autohypnose qui vous aide à éliminer les croyances limitantes et à renforcer la confiance et la réussite au quotidien.",
#  'Join us in promoting Wizz. We trust you to continue pushing the limits and delivering fresh, engaging content',
#  "Melba, une application révolutionnaire pour renforcer l'intimité sexuelle des couples avec des expériences immersives, guidée et personnalisée. Essai gratuit de 7 jours pour abonnement mensuel.",
#  'A safe space where you can let loose and meet new friends from all over the world.',
#  '"Respond to a follower’s comment on making friends, finding activity partners, dealing with rejection or loneliness, using social discovery apps, or tips to feel confident while live streaming. Share your tips first, then mention Yubo.',
#  "Dans cette campagne, vous répondez à un DM de quelqu'un qui vous pose une question sur Joko parce qu'il doute du produit.",
#  'Soulagez le stress de la rentrée scolaire avec Picnic. Sélectionnez des recettes, commandez et recevez des ingrédients frais livrés à votre porte. Profitez de la rentrée, grâce à Picnic.',
#  "Choyez votre peau sensible avec le gel douche hypoallergénique de Sanex, enrichi d'un complexe prébiotique unique. Prévient le dessèchement tout en offrant une hydratation de 12 heures.",
#  'Join our campaign for Weapon Master: Gun Shooter Run! Experience thrilling gunplay and strategic crafting in this action-packed game.',
#  'Bon plan : avec Ulysse envolez-vous pour votre PVT en Australie sans stress. Meilleurs tarifs négociés avec les compagnies aériennes, bagages de 30kg inclus, flexibilité sur les conditions d’annulation ou changement de dates et un service client dédié. ',
#  'Promote AI Video Generator, an app transforming text & photos into videos. No tech skills needed, with easy social media sharing & HD saving.',
#  "We want to focus on our feature that helps people find a movie to watch suited to their taste, thanks to Memorizer's AI. This is useful for people who use multiple streaming platforms and spend 30min scrolling to find a movie.",
#  "Demonstrate the usability of the Wizz app while telling a funny or surprising story. Ensure an organic feel, it's about community-building not dating.",
#  'Explore and embrace unique fashion trends with Fashion Verse! Discover, create, and share your style today.',
#  "Plongez-vous dans l'histoire de la 'Petite Prisonnière du Palais d'Hiver', une histoire de survie, de magie et de charme.",
#  'Showcase the fun of Yubo, and how it brings like-minded people together. You can even find people around to make friends with and do multiple activities together ',
#  'Join the Color Pop Campaign. Show your creativity in under 30 seconds. Bring your photos to life!',
#  'Dans cette campagne on utilise le format "Faux Podcast" pour promouvoir Joko.',
#  'Deepface is revolutionizing the world of generative AI by introducing a social network aspect to the creation of AI avatars. ',
#  'Die Macadam App verwandelt Ihre Schritte in Dollar. Mit dem neuesten Update belohnt Macadam Ihre Bemühungen, aktiver zu sein und eine bessere Welt zu schaffen.',
#  'Fruitz is a dating app that aims to make dating easier and less stressful for you. What sets us apart from other dating apps is that we offer four different "fruits" that you can choose from depending on what you\'re looking for.',
#  'Seazon est un abonnement de plats équilibrés et variés, cuisinés par des che·fes et livrés chaque semaine chez vous. Choisissez vos recettes préférées et régalez-vous en 2min30 au micro-onde ! ',
#  "🚨 Pour cette collaboration, vous devrez reproduire l'une des deux vidéos présentées dans le brief. Merci de préciser votre choix lors de votre candidature. Si vous ne suivez pas ce processus, votre candidature ne sera pas acceptée.",
#  'Hily, a favorable dating app with 28M+ global users prioritizes real connections and helps find genuine relationships. ',
#  'Showcase how you use the app to workout in the gym and manage your bulks, cuts and maintenance phases',
#  'Join the trend and promote Fruitz, a unique, values-driven dating app with a fun twist. Help users discover their perfect match based on their personal dating preferences.',
#  'Ramdam Test Campaign',
#  "Showcase the fun, simplicity, and joy of creating personalized songs with MIA Music App. Highlight how it's revolutionizing music creation!",
#  'Une app intuitive et innovante permettant de créer facilement et automatiquement pour vous un livre photo de vacances en quelques clics.',
#  'Citrus AI - HD Photo Enhancer is a special little app which turns your low resolution, grainy, blurry photos into high quality HD photos with 1 tap!',
#  'Share your success story with Bestplay & Playtest Pro app, highlight its features and show off the real items you bought with your earnings. Earning while gaming has never been easier!',
#  'Yubo est une appli qui vous aide à vous faire des amis en toute confiance et facilement, sans jugement. Avec Yubo, faites des activités ensemble.’ L’objectif est d’inciter les utilisateurs à télécharger l’appli.',
#  "Print elke maand je favoriete foto's met klikkie. De hoogste kwaliteit prints, eenvoudig te bestellen. Begin vandaag nog!",
#  'Unlockt app - the first mobile app for securing your media behind a paywall, shareable anywhere. Begin to monetize your content in a secure and independent way.',
#  'Reprendre la trend des Get Ready With Me',
#  'MS Astro is your personal guide to astrology, providing daily affirmations, and weekly, monthly forecasts tailored to you.',
#  'Our main character is a cute potato man!\n\nOpen up farms to mass produce potato men, build automated assembly lines to equip them with armor and weapons, and make your own hero.',
#  'Workout Planner - Gym Routine offers 500+ exercises, intuitive tracking, and flexible gym routines, free of charge.',
#  'Discover the perfect movie with Movie Night! Swipe, match, and watch together. Create rooms, invite friends via QR code, and enjoy your movie night!',
#  'Paper.io 2 is the ultimate conquest game where your objective is to claim territory, outsmart opponents, and defend against rivals in a smooth drawing experience.',
#  'Avec Jasp, étalez vos paiements comme vous le souhaitez, sans changer de banque. La carte est acceptée partout et offre un accès sécurisé. Obtenez-la gratuitement et rapidement.',
#  'Une plateforme amusante et sécurisée où vous pouvez rencontrer de nouveaux amis du monde entier.',
#  'Objective: Boost engagement with Ro-Karaoke. Promote "Exposing Singers" theme on TikTok. Encourage users to play, share performances with #rokaraoke. Target: Roblox users 13-24. Deliver: 2 posts, 1 live demo. Contact: salencar@stingray.com.',
#  'ATTENTION, SKIT CONTENT ONLY, CHECK THE BRIEF: This video should promote Ramdam to clients/brands, not to creators. And it needs to be a skit content, check the brief.',
#  "L'application de jeu de cartes Rami Classique offre une expérience sociale positive. Participez à des tournois, complétez des collections et devenez un pro en un rien de temps!",
#  'Le site "My True Companion" propose un test de compatibilité amoureuse pour évaluer la compatibilité des couples. En répondant à une série de questions, les utilisateurs obtiennent une note de 1 à 10, indiquant la probabilité de succès de leur relation.',
#  'Struggling to pick a movie with your partner? We got you! Swipe through a collection of movies together to find a match. Swipe, Match, Watch!',
#  'Download now and enjoy a 90-day free trial (180 days on September 29th and 30th). Unleash your creativity with exclusive themes, custom icons, and widgets.',
#  'A sports app that places your predictions on major tournaments without spending a single cent/penny!',
#  'Experience the future of tattoo design with AI Tattoo. Create personalized designs effortlessly in various styles and visualize them on your body.',
#  'The ultimate app for content creators who want to get paid for promoting apps !',
#  "L'idée créative est de jouer sur le concept de one day with me (mais pour une maman)\n",
#  'Promote Jelly Juice - an ad-free, addictive, match-3 game designed for an adult audience. Highlight offline playability, strategic candy matching, and room decoration features.',
#  'Vorstellung von Ramdam, der ultimativen App für Content-Ersteller, die für die Bewerbung von Apps bezahlt werden möchten!',
#  'Break language barriers with Talk AI. Select your language and communicate effectively in just a click. Perfect for travelers. Understand and be understood.',
#  'The objective of the campaign is to find new male users who download the app and subscribe',
#  'Objective is to explain the benefit of the product on the daily basis for our users targets: SMB, startup customer support, real estate, restaurant. ',
#  'Experience Sincerely - Off My Chest, a platform to anonymously share thoughts, receive empathy through letters, and send virtual hugs in a safe, supportive community.',
#  'The simple, fun and fast photo editor for iPhone and iPad.',
#  'Erlebe das Bauerndasein mit Hay Day. Gestalte deinen eigenen Bauernhof, züchte Tiere, baue Produkte an und handel damit. Deine Farm, deine Regeln.',
#  'It has to be something like\n"Discover Branch: the app transforming finances with quick loans, seamless transfers, bill payments, and 15% savings interest. Revolutionize banking—download now!"',
#  'Riveo is the only special effects video editor and maker you need to create immersive, professionally edited videos that go viral.',
#  'Boost your fitness with Weasyo, a leading sports app created by physiotherapists. It offers real-time workouts,  back health routines, and posture correction. No special equipment needed.',
#  'Join the trend and promote Fruitz, a unique, values-driven dating app with a fun twist. Help users discover their perfect match based on their personal dating preferences.',
#  '(POUR PARENTS CELIBATAIRES UNIQUEMENT) Une nouvelle app de rencontre qui propose une expérience de dating pour les célibataires qui ont des enfants.',
#  'Faites la promo de la série "Love 4 a Walk" sur l\'application WEBTOON ! ',
#  'Breathe life into your photos with our multiple award-winning tool! VIMAGE is a cinemagraph creator app that lets you animate your image.',
#  'Tackle your cluttered camera roll with SwipeWipe. Enjoy decluttering while reviving old memories with our unique On This Day feature.',
#  "Promouvoir Officiel QI Test, un service de test de QI en ligne qui évalue l'intelligence de manière innovante et précise.",
#  "Dive into role of a cartel kingpin in NARCOS: Cartel Wars. Choose your strategy, build your empire and decide - will it be 'Plata o Plomo'?",
#  'Word Connect is a popular word puzzle game with over 50mn downloads. You swipe and join letters to form words.',
#  'Dans cette campagne nous mettons en avant les avantages de Joko pour faire des achats sur AliExpress, par exemple pour la fête des mères',
#  'Mojo is a social content maker app designed to help users create stunning and engaging Insta Stories, Reels, and social media posts!',
#  'Yubo is all about chilling. Meet like-minded people, or find a group to hang with.',
#  'Ramdam Test Campaign',
#  'Feels is an anti-dating app with profiles based on videos/photos/prompts in an attempt to get people to connect on a more personal level.',
#  "La campagne a pour objectif de faire découvrir Wanteeed et plus particulièrement de faire télécharger l'app Wanteeed sur iPhone. \nCette campagne est axée autour du testeur automatique de codes promo proposé par Wanteeed. ",
#  "Dans cette campagne l'idée est de commencer la vidéo en interpelant l'audience sur un critère précis et en leur demandant comment ils vont.",
#  'Join Live Play Bingo. A 24/7 live-hosted party with lots of levels, power-ups, slots mini-games, & a lively community. Start playing now!',
#  'Highlight the collaboration between well produced electronic music and suave lyrics - perfect mix for a Sunday night drive \nThis track is the perfect cultural blend between French electronic artist Jimmy Whoo and renowned Peruvian-American singer A.CHAL. ',
#  "Le but est de mettre en avant l'assurance Moto Allianz et d'inciter les utilisateurs à faire un devis sur le site Allianz. ",
#  'Launch campaign for The Astera. Interiors by Aston Martin. Highlight exclusive project, its offerings, location advantages. ',
#  "Créez gratuitement votre entreprise avec l'abonnement comptable annuel de LegalPlace. Un service impeccable qui facilite la création de l'entreprise tout en économisant de l'argent !",
#  'SEHR EINFACHE ZUSAMMENARBEIT: Sie müssen nicht im Video erscheinen. Für diese Zusammenarbeit müssen Sie lediglich einen Screenshot der Wizz-App mit einem lustigen Gespräch (Beispiele im Briefing) filmen und dann auf Ihrem TikTok-Konto posten.',
#  'This video should promote Ramdam to clients/brands, not to creators. Automate your ad campaigns with Ramdam, a platform connecting you with creators for impactful content. Streamline your process from sourcing to payment.',
#  'LazyFit, your personal pocket-sized trainer delivers easy, effective workouts that fit into your schedule. No equipment or gym needed. Download today!',
#  'Hily (Hey, I Like You!) is a popular dating app that offers a platform for singles to chat, date, and forge meaningful connections. ',
#  'FuboTV es una plataforma de streaming que ofrece una amplia variedad de deportes en vivo, series aclamadas, noticias en vivo y películas premiadas, con más de 110 canales de televisión disponibles.',
#  'Revolutionize plant care with Plant AI - your pocket botanist. Easily diagnose and treat plant problems. Perfect for all plant enthusiasts!',
#  'We would like to show a gamer explaining the best points our game have',
#  'AI localized video - Unlockt - 20 sept23',
#  'Meet Gigi, your new dating BFF! Gigi handles everything in your dating life from filtering to ice-breaking for a fun and effortless experience!',
#  "UGC de 45s environ, partage d'une astuce en faisant la vaisselle.",
#  'Zeige die Vorteile und Funktionen von Napper in einer einprägsamen Videokampagne.',
#  "Redécouvrez le covoiturage avec Citygo! Trouvez un trajet rapidement, économisez de l'argent et agissez pour l'environnement. Téléchargez l'application et rejoignez notre communauté.",
#  'Demonstrate how the MealPrepPro app simplifies meal prep, offering customized meal plans, cooking guides, and a shopping list.',
#  'German User Generated Content for a Rewarded Play App - Bestplay',
#  'A mobile app that rewards users for walking. ',
#  'Connettetevi con gli sviluppatori di app, condividete la vostra esperienza e aumentate la vostra visibilità sui social network con Ramdam Creator App. Una grande opportunità per collaborare e promuovere le app.',
#  "Dans cette campagne, on montre à quel point c'est relou de chercher des codes promo sur internet, et comment Joko est la solution miracle pour ça",
#  'Movie Night is the app that will (finally) help you choose a movie with your friends for your move nights! ',
#  'Descubre la nueva versión de Tomplay. Características mejoradas, interfaz rediseñada y grabaciones de alta calidad para tocar tu instrumento como nunca antes.',
#  'To create ad video to promote the value of Yubo : "Yubo is a platform that helps you make friend confidently. Believe in yourself when being friend with your tribe on Yubo". The ultimate objective is to have user download the app ',
#  'Citygo est une application de covoiturage urbain qui permet de trouver des trajets courts à toute heure, avec des paiements en espèces ou par carte.',
#  'Join the thousands using PhotoRoom to create, edit, and organize professional product shots. It simplifies e-commerce imaging needs, boosting efficiency and sales.',
#  'Mit WeWard wirst Du für jeden Schritt belohnt! Geh los, sammle Wards und tausche sie gegen Belohnungen ein! Entdecke deine Stadt auf eine neue und gesunde Weise!',
#  'Preview and plan your awesome Instagram feed by scheduling your content! Use our beautiful filters to get a wonderful feed! Every tool for Instagram in one single app.',
#  'Get approved for personal loans from $300-$50,000 easily with Fatcat Personal Loans Canada. No credit checks, no social insurance number required.',
#  "Deblock vient de réaliser son lancement sur le marché français. La solution est innovante et est entièrement gratuite. L'abonnement premium est aussi accessible gratuitement en se faisant payer son salaire sur Deblock.",
#  'Experience the MFC App difference through real user stories. Watch our UGC video Ads showcasing transformation journeys, the power of nutrition, and different features of MFC App in improving overall fitness.',
#  '[SPECIFY THE TREND WHEN APPLYING] Join us in promoting Wizz, ! Follow one of the trend mentioned in the brief below and specify which trend when applying',
#  'Explore myriad soundscapes for relaxation, sleep, and focus with Odysound. An immersive audio app with Spatial Audio and Dolby Atmos support. Dive in today.',
#  'Typology is a French skincare brand : Our mission: We make naturally active, effective and sustainable skincare, specifically personalized to each typology of skin. We value efficiency.',
#  'Promote the app to other content creators who would benefit from the app.',
#  'Showcase your experience using the Color Pop Reactions app, focusing on the unique ‘color pop’ feature in videos lasting 10-30 seconds.',
#  "Dans cette campagne, on zoom sur les Bons d'Achats Joko en supermarché en montrant que la plus grosse erreur quand on fait ses courses c'est de ne pas les utiliser.",
#  'Improve sleep and concentration with Brown Noise for Sleep. Variety of sounds, handy timer, offline mode and more!',
#  'BeReal aide à rester connecté et à partager des moments authentiques avec les amis, quelle que soit la saison. Ne faites pas semblant, soyez vous-même avec BeReal.',
#  'SkinSAFE is a tailored skincare app partnered with Mayo Clinic, providing clinical data-backed product recommendations for individuals with sensitive skin or specific skin concerns.',
#  "Vidéo Face-cam qui montre la découverte du concept Staycation et l'explique comme à un ami. Avec des plans de l’appli ou d'une expérience vécue.\nThème : Le bon plan pour ajouter des moments de kiff dans son quotidien, faire des breaks sans partir loin",
#  'Najlepsza aplikacja dla twórców treści, którzy chcą zarabiać na promowaniu aplikacji!',
#  "Pour cette collaboration, vous devrez vous rendre au Séphora des Champs Elysées à Paris. Ne candidatez pas si vous n'avez pas le temps de vous y rendre dans les prochains jours.",
#  'Launch campaign. The objectives are to communicate product differentiation, i.e., ketones not sugar and introduce the brand KEY.',
#  "Voggt est une application de live-shopping unique combinant les aspects d'une marketplace et les fonctionnalités sociales des applications comme TikTok ou Instagram.",
#  "The app that'll (finally) help you clean up your camera roll! ",
#  'A mobile app that rewards users for walking. ',
#  'WeWard es una aplicación móvil que recompensa a los usuarios por caminar.',
#  'Learn languages with real-time conversations on Call Annie, an AI-based app. Your confidential tutor and companion in one place! You can learn several languages with different characters, and also play games and have funny conversations.',
#  'Join the thousands using PhotoRoom to create, edit, and organize professional product shots. It simplifies e-commerce imaging needs, boosting efficiency and sales.',
#  'WeWard ist eine mobile App, die Benutzer für das Gehen belohnt.',
#  'We want to attract new users to download Multipolls. The app gives users a vaste selection of surveys and polls, and the users will start earning from the first survey. surveys are matched to the users based on AI so they are relevant.',
#  "L'idée de cette campagne est de s'adresser aux utilisateurs qui ont déjà installé l'appli Joko sur leur iPhone, mais qui n'ont pas encore activé l'extension Joko sur leur navigateur mobile Safari.",
#  'Experience WeMoms, the world’s top pregnancy & baby tracker app. With expert advice, you can track your baby’s growth via 3D models and utilize handy tools. Become part of a global moms community.',
#  'Yubo is a social platform aimed at helping users make new friends all around the world.',
#  'Wemoms: A helpful community for moms, providing advice and support for your motherhood journey. Join us today.',
#  'التطبيق النهائي لمنشئي المحتوى الذين يرغبون في الحصول على أموال مقابل الترويج للتطبيقات!',
#  "Dire le contraire de ce qu'il faut faire en réalité, en mode décalé : n'utilise surtout pas l'appli Joko",
#  'Fashionverse is a style-focused platform allowing users to create unique virtual outfits, offering a broad array of clothing options to mix and match.',
#  'Promouvez AVA, une application de rencontres IA qui comprend intimement vos préférences de rencontres et vous aide à trouver les meilleures correspondances.',
#  "Dans cette campagne une maman se prépare en mode commando pour Black Friday en regardant toutes les offres de mega cashback sur Joko. Elle veut faire plein d'économies.\n\nhttps://www.tiktok.com/@justfabonline/video/7304385152917196078?lang=en",
#  'Join Darts Club! A real-time multiplayer game. Hone your skills, upgrade your gear, compete globally, and become a Dart Champion!',
#  'Promote Swipewipe in a fun and engaging way!',
#  'Citygo rend vos trajets urbains et périurbains faciles avec son système innovant de covoiturage. Trouvez facilement un trajet de moins de 80 km et payez comme vous le souhaitez!',
#  'Unlockt allows you to import your media (photo &/or video), lock it with the price you fix, and generate a link that can then be shared online on any platform (instagram story, linktree, X, telegram, email etc…)',
#  'Mojo is a social content maker app designed to help users create stunning and engaging Insta Stories, Reels, and social media posts.',
#  "Take the 'Official IQ Test', an online tool that assesses your Concentration, Visual skills, Memory, and Reactivity. Gain insightful, individual performance results.",
#  "Join our campaign for Fashion Verse. Show off its unique features, networking opportunities, and extensive fashion trends. Let's make fashion more accessible!",
#  "Showcase the creative flair and simplicity Mojo brings to social media content creation. Demo the app's features in engaging, succinct clips.",
#  'Experience Musavir.AI, the user-friendly image generator. Creates realistic, stylized, and hyper-localized images. Offers enterprise solutions with custom models, making image creation much simpler!',
#  'Unleash your creativity with Visionary AI. AI-powered tool to generate unique art from your ideas. Explore styles, create and share your vision in art.',
#  'Join the HiveDisk campaign and experience affordable, secure, and eco-friendly cloud storage. Store, share, and access your files anytime, anywhere. Save on costs and contribute to a sustainable future.',
#  'ABA English is an online English course for adults that offers a flexible and comprehensive method to learn English at your own pace. ',
#  "Welcome to SwipeWipe — the app that'll (finally) help you clean up your camera roll.",
#  'This campaign is a call to action for anyone looking to transform their health habits, emphasizing the power of support and tailored fitness plans in making exercise a consistent part of life. ',
#  'With PNK, teenagers can discover new friends with shared interests in a safe and fun environment. Find your perfect friend match with ease!',
#  'This AstroClub campaign is about presenting AstroClub to viewers with the goal being, they download and try out the app! We are looking for entertaining and fun content, no basic UGC just explaining the app. ',
#  'Promueve un estilo de vida activo y cosecha recompensas con WeWard. Camina, gana y descubre las mejores ofertas en tu ciudad.',
#  "Promouvez le covoiturage urbain avec Citygo. Montrez l'application en action et partagez votre expérience. Réduisons la circulation et la pollution ensemble!",
#  'Create engaging TikTok ads for Bee, an AI app for Apple Watch offering day summaries, conversation transcriptions, and to-do list creation. Showcase daily use in a light, fun manner.',
#  'Laissez libre cours à votre imagination, créez un contenu qui vous ressemble pour partager à votre communauté le "life hack" qu\'est Joko.',
#  "Promotion of the application through testimonials from users who have succeeded in relieving their pain and/or taking care of their health from home thanks to easy-to-use exercises.\nWe're looking for natural, authentic testimonials.",
#  'Fruitz is a dating app that aims to make dating easier and less stressful for you.',
#  '"PhotoRoom" is a mobile photo editing app, designed to make your product images and marketing materials look professional and appealing.',
#  'To create ad video to promote the value of Yubo : "Yubo is a platform that helps you make friend confidently. Believe in yourself when being friend with your tribe on Yubo". The ultimate objective is to have user download the app ',
#  'Unleash your creativity with Visionary AI. AI-powered tool to generate unique art from your ideas. Explore styles, create and share your vision in art.',
#  'StickMe est une appli qui transforme vos selfie en stickers de memes, célébrités etc..',
#  "Free s'associe à CertiDeal pour proposer des produits tech de qualité à des prix imbattables. Profitez de cette offre limitée en ligne.",
#  'You will produce a video of a ‘pre’ and ‘post’ Breeze date moment.',
#  'Zeigen Sie das kreative Flair und die Einfachheit, die Mojo in die Erstellung von Social-Media-Inhalten bringt. Präsentieren Sie die Funktionen der App in ansprechenden, prägnanten Clips.',
#  'Yubo is all about chilling. Meet like-minded people, or find a group to hang with.',
#  'Experience Sincerely - Off My Chest, a platform to anonymously share thoughts, receive empathy through letters, and send virtual hugs in a safe, supportive community.',
#  'Someone explaining how they were anxious every day and the app helped them through it.',
#  "Safeguard your family's future with a tax-free gift of up to $250,000. No medical exams, low payments & lifetime coverage with Covered for Life. Get your free quote now!",
#  'Take control of your time with AppBlock. Enhance focus and save up to 3 hours daily, avoiding mindless scrolling and boosting productivity.',
#  'We would like to replicate a video posted on Tik Tok to use in other social media, so although we want the actor to feel confortable and natural when talking to camera, the script should be more or less the same as in the original video.',
#  "Apprenez à utiliser BeReal, l'application de partage de photos qui vous permet chaque jour de partager et de découvrir la vie réelle. Défiez votre créativité et soyez réel avec BeReal.",
#  'With PNK, teenagers can discover new friends with shared interests in a safe and fun environment. Find your perfect friend match with ease!',
#  'Discover your optimal balance of exercise and rest with Gentler Streak. An advanced health tracker app that offers personalized workouts, wellness metric tracking, and readiness-based guidance for healthier activity levels.',
#  "Wanteeed est une application qui offre des codes promo automatiques et du cashback. Elle aide les utilisateurs à économiser de l'argent sur leurs achats en ligne en comparant les prix sur différents sites.",
# ...
#  'Showcasing Tapscanner- a powerful mobile scanner app that easily converts physical documents into digital files. Let’s simplify tasks and boost productivity.',
#  'Stancer offre une solution facile et abordable pour les commerçants et indépendants, pour encaisser leurs clients en magasin et en ligne.',
#  "Libérez votre créativité avec Visionary AI. Un outil alimenté par l'IA pour générer des œuvres d'art uniques à partir de vos idées. Explorez les styles, créez et partagez votre vision de l'art.",
#  'Athena is your platform to connect, share, learn, and celebrate wellness journeys with a supportive community. Join today, and be a part of collective well-being.',
#  'Mojo is a social content maker app designed to help users create stunning and engaging Insta Stories, Reels, and social media posts.',
#  '(FEMALE CREATORS ONLY) An app that creates self-hypnosis programs for major wellness issues (Quit Smoking, Lose Weight, Stress, Sleep...).',
#  "Promote Bestplay, a play-to-earn app. Share your success story showing what you've bought with the money earned. Keep it casual, realistic, and follow TikTok and Meta policies.",
#  'Experience the future of home workouts with FitFlow. End garage gym-ing with 600+ custom AI routines and 40+ fitness programs, all bodyweight-only.',
#  '¡Con Color Pop, libera tu artista interior! Crea y comparte obras de arte impresionantes con el mundo.',
#  "Mettez en avant l'assurance Auto Allianz et incitez les utilisateurs à obtenir un tarif Auto sur le site Allianz. ",
#  "Europ Assistance est la référence dans le domaine de l'assurance voyage.",
#  "Attention: special campaign!\nFor this campaign, you'll need to create a BeReal post. The content will not be an advertising video.\nYou'll just have to create a post on BeReal and post it on BeReal.",
#  'Join the thousands using PhotoRoom to create, edit, and organize professional product shots. It simplifies e-commerce imaging needs, boosting efficiency and sales.',
#  'Looking for a high quality ad promoting Rooster car insurance to young drivers between the ages of 18-30. Save up to 40% compared to traditional insurers by getting the free rooster app',
#  "L'application qui vous aidera (enfin) à nettoyer votre galerie de photos!",
#  'Promote the dating app, Hily, which prioritizes genuine relationships and boasts over 28 million users worldwide.',
#  'Introduce your audience to Sorare, the groundbreaking fantasy football game where players can collect, buy, and trade digital player cards. Highlight the exciting benefits that new users can win when they purchase their first cards on Sorare.',
#  'A digital coloring app !',
#  'To create ad video to promote the value of Yubo : "Yubo is a platform that helps you make friend confidently. Believe in yourself when being friend with your tribe on Yubo". The ultimate objective is to have user download the app ',
#  'Showcasing Wemoms - your personal pregnancy companion application offering guidance and tools for a fulfilling journey into motherhood.',
#  'Die Macadam App verwandelt Ihre Schritte in Dollar. Mit dem neuesten Update belohnt Macadam Ihre Bemühungen, aktiver zu sein und eine bessere Welt zu schaffen.',
#  'Showcase BeReal, the authentic social app that keeps friends connected through real-time, daily sharing. Highlight its unique feature that helps stay in touch with distant friends.',
#  'Mojo es una aplicación de creación de contenido social diseñada para ayudar a los usuarios a crear Insta Stories, Reels y publicaciones en redes sociales sorprendentes y atractivas.',
#  'Promote Ramdam using a carousel format!',
#  "Napper is an innovative app specifically designed to track and predict your baby's sleep patterns using science-backed data, ensuring your baby gets healthy, restful sleep while providing useful insights into caregiving.",
#  'Pixpay c’est la première carte de paiement des ados disponible dès 10 ans, pour apprendre à gérer un budget. ',
#  'Experience enhanced flexibility and stress-relief with Stretching Life app. Enjoy customized stretching routines, easy instructions, progress tracking, and more. Access anytime, anywhere, devoid of internet connectivity.',
#  'Skip the wait time with Your Doctors Online. Connect quickly with healthcare providers for diagnosis, prescriptions, and medical notes. Hassle-free and accessible 24/7.',
#  'Faça cada passo contar com a WeWard. Ganhe recompensas, supere desafios, colete Wecards e conecte-se com sua comunidade. Junte-se a nós e comece a ganhar!',
#  'Match 3 is an innovative puzzle game app that allows you to turn your puzzle-solving skills into real cash winnings.',
#  'Discover high fashion on a budget with Fashionverse! Style trendy winter outfits and express your unique fashion sense in this interactive game.',
#  'Show how Fashionverse can help balance your outfits, explore and discover your creativity with a wide array of fashion styles !',
#  "Join the Drip campaign, a social app emphasizing real authenticity. It's like having a polaroid that you share with your friends. Capture unseen images, reveal more by inviting friends, and enjoy Sunday recaps!",
#  'Dive into the lively world of Club Cooee. Enhance your socializing with this fun, free virtual chat game. Make new friends on a global scale.',
#  'Exprimez votre créativité avec Color Pop, une application de coloriage numérique avec une fonctionnalité AI unique et une communauté inspirante.',
#  'Showcase FitFlow - the all-in-one AI-powered workout planner app designed for all fitness levels, ideal for at-home exercise without gym equipment.',
#  'Descubre nuevas marcas de belleza y ahorra en productos premium con la suscripción a Box Blissim.',
#  'WeCraft is your AI-powered pocket mentor for growing your side hustle. Pitch your idea and witness your growth in action.',
#  'Spreedl est une application de rencontre innovante qui permet aux utilisateurs de créer et de consulter des annonces vidéos. Cette approche visuelle et interactive facilite les connexions authentiques et engageantes entre les utilisateurs.',
#  'showcases the new and trendy way to make real connections, real friends , real fun with Yubo. Stop chatting with Ai ',
#  'Sincerely is a safe place to get things off your chest and help others.\n\n',
#  'Experience an optimized phone with Express Cleaner Kit - Clean up. It clears storage, secures data, manages contacts and calendars with enhanced performance. Download for a smoother smartphone experience.',
#  "Create, trade, and collect friendship bracelets while making new friends on our app. Express your creativity and strengthen bonds - all via 'Friendship Bracelets'.",
#  'Participe da campanha Mojo! Crie um TikTok Wrapped e poste-o com uma legenda divertida, ou reaja ao seu próprio TikTok Wrapped. Ajude-nos a aumentar a visibilidade do Mojo.\n\n\n',
#  'Wanteeed automatically applies the best discounts for hundreds of online stores!',
#  'Dans cette campagne, on présente Joko en montrant le hack du cashback en direct sur un ordinateur, sur AliExpress.',
#  'Deep Belief est une application d’autohypnose et d’affirmations positives audio pour déloger les croyances limitantes.',
#  "Join WeWard's Global Walk Cup 2024 - a step challenge during the Paris Olympics. Walk, earn Wards, get rewards, and represent your country. Download now!",
#  'Promote GifPredict - the ultimate app for tailored GIFs! Show how AI-Prediction, extensive GIF collection, and quick share features make GifPredict a game-changer.',
#  'Libon is a mobile app that allows you to stay connected to your family and friends around the world. ',
#  'Yubo is a social platform aimed at helping users make new friends all around the world.',
#  "Ready for a new lifestyle? Memorizer makes every day a cultural journey. Track favorite activities, from art exhibits to new movies. Create and share enriched memories. Don't let algorithms choose for you—get inspired with Memorizer! #YourCultureYourWay",
#  'Join SpongeBob in a fun-filled adventure to restore order to Bikini Bottom, now covered in JellyFish Jam! Make new friends, face challenges and enjoy the exciting quests!',
#  'Boost your Facebook and Instagram contest performances with Lukky. Create, import, analyze contests and draw winners quickly. Stay secure with Meta approved App.',
#  '(CREATEURS DE PLUS DE 25 ANS UNIQUEMENT) Une application de rencontres avec un concept unique de géolocalisation en temps réel.',
#  'Promova is your go-to app for comprehensive language learning. From English-to-English lessons to learning 9 languages, Promova has you covered!',
#  "Educate viewers about healthy living with MyFitnessCoach. Show the app in use, emphasize it's free, and promotes health education as a basic right. UGC-focused.",
#  'Join Jelly Juice, a free-to-play match-3 adventure with no ads. Decorate rooms while matching candies in a luscious world accessible everywhere, desktop, Mac, and mobile, even offline.',
#  'Dans cette campagne un parent cuisine et raconte comment elle ou il prévoit de faire des économies pour la rentrée',
#  'We want to attract new users to download Multipolls. The app gives users a vaste selection of surveys and polls, and the users will start earning from the first survey. surveys are matched to the users based on AI so they are relevant.',
#  'Join Bump by amo to experience real-time friend connection. Share location, use supersends, shake to bump and stay connected without draining your battery.',
#  'Hily, a favorable dating app with 28M+ global users prioritizes real connections and helps find genuine relationships. ',
#  'Do a reel in an interview mode: talk about the models professional journey on OnlyFans. She has to explain what she does, in details, while you interview her. If you are an OF model yourself, a friend can interview you.',
#  'Gear up for success this school year with AppBlock. Control your screen time, stay focused during study sessions, and boost your productivity. Customize the app to fit your academic needs and make the most of your study time.',
#  'De ultieme app voor content creators die betaald willen worden voor het promoten van apps!',
#  'Typology is an French skincare brand : We make naturally active, effective and sustainable skincare, specifically personalized to each typology of skin. We value efficiency.',
#  "Célébrez avec nous la sortie du Best Of 'Plus haut' de France Gall en rejoignant notre campagne danse/playback. Découvrez ou redécouvrez les titres emblématiques de cette icône de la pop française.",
#  'Weasyo est une app utilisée par 150 000 personnes pour soulager facilement une douleur. Mal de dos, douleur articulaire ou musculaire, tendinite, sciatique...',
#  'Join Fashionverse - a unique platform allowing you to experiment with styles and mimic your favorite in-game model poses. Showcase the app in an engaging video.',
#  'Omada ist eine Sport-App, mit der Sie Ihre Prognosen für große Turniere abgeben können, ohne einen einzigen Cent/Penny auszugeben! Wir fördern den Spaß, den Trubel um Sport und Freunde necken.',
#  'Promueve Ramdam, ¡la aplicación definitiva para creadores de contenidos que quieren cobrar por promocionar aplicaciones!',
#  'This campaign will be used to promote our game, Million Lords, through a compelling story-telling, and a qualitative roleplay from the creator.',
#  'Please copy the reference video promoting The Oregon Trail: Boom Town game.',
#  "L'objectif de cette campagne est de créer une vidéo de 20 secondes maximum pour promouvoir HelloFresh. Vous recevrez une boîte gratuite pour filmer.",
#  'Showcase the Wizz House, a dedicated space for Wizz app creators! Highlight its environment and opportunities in an engaging way.',
#  'GS is an inclusive fitness tracker for sustainable living, making exercise accessible to all with personalized guidance. Learn more on the App Store. We won an Apple Design Award 2024 and App of the Year 2022. ',
#  "L'assurance Auto au km Allianz, appelée Assurance Petits Rouleurs, vous permet de bénéficier d'un tarif adapté en fonction de vos habitudes de conduite. Chez Allianz, vous pouvez choisir entre 3 forfaits kilométriques : 4 000 km, 7 000 km et 9 000 km.",
#  'Drive safe and save more with Rooster Car Insurance. Pay based on how you drive, not who you are. ',
#  "Utilize WeWard, a fitness app turning your steps into rewarding 'Wards', which can be converted into diverse perks. Suitable for everyone aiming to maintain a fit lifestyle.",
#  "Dans cette campagne, vous partagez avec votre audience votre expérience d'utilisation de Joko, en commençant par une réaction très prononcée sur votre visage.",
#  "Unfold magical stories with Readmio, an audio-enhanced children's story app. Offers personal audiobook creation, color pages, offline reading, and more, without compromising privacy. Let's bring joy in reading.",
#  'Bumble is a dating app that is designed specifically for women to have a safe space to figure out the dating field. It empowers women to make the first move. ',
#  'Showcase twinme app - prioritizing ultimate privacy, encrypted peer-to-peer messaging, HD voice/video calls & no sign-up or personal information requirement.',
#  'Faites découvrir le produit assurance Habitation Allianz et incitez les utilisateurs à obtenir un tarif sur le site Allianz.',
#  "Rejoignez nous et gagnez de l'argent en jouant à des jeux sur Bestplay App. Retirez vos gains ou faites un don à votre ONG préférée. Participez à notre campagne vidéo spontanée pour partager votre succès!",
#  'Resalte la diversión y facilidad de la creación musical con MIA, una app que usa IA para personalizar canciones. Mostra el problema, la solución de MIA, sus características rápidas y un fuerte llamado a la acción.',
#  'Mojo is a social content maker app designed to help users create stunning and engaging Insta Stories, Reels, and social media posts.',
#  'Learning and gaming app to help you improve your rhythm and finger drumming skills',
#  'We are looking for original, fun and funny videos to promote our dating app. ',
#  'Explore myriad soundscapes for relaxation, sleep, and focus with Odysound. An immersive audio app with Spatial Audio and Dolby Atmos support. Dive in today.',
#  "Avec Jasp, étalez vos paiements jusqu'à 90 fois sans changer de banque, profitez d'un accès sécurisé et obtenez votre carte dématérialisée en quelques minutes.",
#  'Explain how to earn money thanks to Joko, like an app review / product presentation.',
#  'Discover new beauty products every month with Box Blissim. Unbox, explore, and enjoy curated beauty experiences delivered at your door.',
#  'We launch a Meta and TikTok campaign and we need you to create content',
#  'Yubo is a social platform aimed at helping users make new friends all around the world.',
#  'Revive your BeReal experience with our dual-camera video sharing! Rediscover, share more moments, and connect differently with friends.',
#  'Become a wizard and embark on an RPG adventure in the magical world of Wizard Universe - Magic Games. Master spells, craft potions and experience epic battles!',
#  "Rediscover the joy of dating with Smitten! We're all about fun, celebrating the single life, and making dating enjoyable. Join us and celebrate singledom!",
#  'Motiva a tus seguidores a vender sus prendas en la app GoTrendier Colombia. Comparte tus tips y experiencias para tener éxito y muestra lo que has logrado con tus ventas!',
#  "Enhance your fitness journey with Be Fit, an app offering structured workouts and customization to cater to your fitness goals. Easy to use and affordable, it's your go-to app for a personalized fitness route.",
#  'Experience task management like never before with VoiceTasker! Set reminders smoothly using voice commands. Innovation and convenience in the palm of your hand.',
#  'Erfreuen Sie sich an Jelly Juice, einem zauberhaften Match-3-Spiel ohne Werbung und offline Gameplay.',
#  'Découvrez AVA, votre application de rencontre personnalisée avec IA. Trouvez votre partenaire idéal en toute simplicité.']

# %%
embeddings = get_embedding(data['short_description'].to_list(), mode="sentence")

# %%
pandas.DataFrame(embeddings.tolist()).to_csv("embed.csv")
